# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/Projects/Weather_Data_Analysis/Weather Data.csv')

# %%
# Display basic information about the data
print("Data Information:")
print(data.info())
# Out:
# Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB
# None

# %%
# Display basic statistics of the data
print("\nData Statistics:")
print(data.describe().transpose())
# Out:
# Data Statistics:
#                    count        mean        std    min     25%     50%  \
# Temp_C            8784.0    8.798144  11.687883 -23.30    0.10    9.30
# Dew Point Temp_C  8784.0    2.555294  10.883072 -28.50   -5.90    3.30
# Rel Hum_%         8784.0   67.431694  16.918881  18.00   56.00   68.00
# Wind Speed_km/h   8784.0   14.945469   8.688696   0.00    9.00   13.00
# Visibility_km     8784.0   27.664447  12.622688   0.20   24.10   25.00
# Press_kPa         8784.0  101.051623   0.844005  97.52  100.56  101.07
#
#                      75%     max
# Temp_C             18.80   33.00
# Dew Point Temp_C   11.80   24.40
# Rel Hum_%          81.00  100.00
# Wind Speed_km/h    20.00   83.00
# Visibility_km      25.00   48.30
# Press_kPa         101.59  103.65

# %%
# Renaming columns for consistency
data.rename(columns={'Rel Hum_%': 'Humidity', 'Weather': 'Weather_condition'}, inplace=True)

# %% [markdown]
# **Exploratory Data Analysis**

# %%
# Data Exploration
print("\nNumber of unique values in each column:")
print(data.nunique())
print("\nUnique weather conditions:")
print(data['Weather_condition'].unique())
# Out:
# Number of unique values in each column:
# Date/Time            8784
# Temp_C                533
# Dew Point Temp_C      489
# Humidity               83
# Wind Speed_km/h        34
# Visibility_km          24
# Press_kPa             518
# Weather_condition      50
# dtype: int64
#
# Unique weather conditions:
# ['Fog' 'Freezing Drizzle,Fog' 'Mostly Cloudy' 'Cloudy' 'Rain'
#  'Rain Showers' 'Mainly Clear' 'Snow Showers' 'Snow' 'Clear'
#  'Freezing Rain,Fog' 'Freezing Rain' 'Freezing Drizzle' 'Rain,Snow'
#  'Moderate Snow' 'Freezing Drizzle,Snow' 'Freezing Rain,Snow Grains'
#  'Snow,Blowing Snow' 'Freezing Fog' 'Haze' 'Rain,Fog' 'Drizzle,Fog'
#  'Drizzle' 'Freezing Drizzle,Haze' 'Freezing Rain,Haze' 'Snow,Haze'
#  'Snow,Fog' 'Snow,Ice Pellets' 'Rain,Haze' 'Thunderstorms,Rain'
#  'Thunderstorms,Rain Showers' 'Thunderstorms,Heavy Rain Showers'
#  'Thunderstorms,Rain Showers,Fog' 'Thunderstorms' 'Thunderstorms,Rain,Fog'
#  'Thunderstorms,Moderate Rain Showers,Fog' 'Rain Showers,Fog'
#  'Rain Showers,Snow Showers' 'Snow Pellets' 'Rain,Snow,Fog'
#  'Moderate Rain,Fog' 'Freezing Rain,Ice Pellets,Fog'
#  'Drizzle,Ice Pellets,Fog' 'Drizzle,Snow' 'Rain,Ice Pellets'
#  'Drizzle,Snow,Fog' 'Rain,Snow Grains' 'Rain,Snow,Ice Pellets'
#  'Snow Showers,Fog' 'Moderate Snow,Blowing Snow']

# %%
# Count of each weather condition
print("\nCount of each weather condition:")
print(data['Weather_condition'].value_counts())
# Out:
# Count of each weather condition:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# Freezing Drizzle                              7
# Snow,Ice Pellets                              6
# Freezing Drizzle,Fog                          6
# Snow,Haze                                     5
# Freezing Fog                                  4
# Snow Showers,Fog                              4
# Moderate Snow                                 4
# Rain,Snow,Ice Pellets                         4
# Freezing Rain,Fog                             4
# Freezing Drizzle,Haze                         3
# Rain,Haze                                     3
# Thunderstorms,Rain                            3
# Thunderstorms,Rain Showers,Fog                3
# Freezing Rain,Haze                            2
# Drizzle,Snow                                  2
# Rain Showers,Snow Showers                     2
# Thunderstorms                                 2
# Moderate Snow,Blowing Snow                    2
# Rain Showers,Fog                              1
# Thunderstorms,Moderate Rain Showers,Fog       1
# Snow Pellets                                  1
# Rain,Snow,Fog                                 1
# Moderate Rain,Fog                             1
# Freezing Rain,Ice Pellets,Fog                 1
# Drizzle,Ice Pellets,Fog                       1
# Thunderstorms,Rain,Fog                        1
# Rain,Ice Pellets                              1
# Rain,Snow Grains                              1
# Thunderstorms,Heavy Rain Showers              1
# Freezing Rain,Snow Grains                     1
# Name: Weather_condition, dtype: int64

# %%
# Show all records where weather condition is 'Clear'
print("\nRecords where Weather Condition is Clear:")
print(data[data['Weather_condition'] == 'Clear'])
# Out:
# Records where Weather Condition is Clear:
#              Date/Time  Temp_C  Dew Point Temp_C  Humidity  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8        50               24
# 114     1/5/2012 18:00    -7.1             -14.4        56               11
# 115     1/5/2012 19:00    -9.2             -15.4        61                7
# 116     1/5/2012 20:00    -9.8             -15.7        62                9
# 117     1/5/2012 21:00    -9.0             -14.8        63               13
# ...                ...     ...               ...       ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8        89                4
# 8698  12/28/2012 10:00    -6.1              -8.6        82               19
# 8713   12/29/2012 1:00   -11.9             -13.6        87               11
# 8714   12/29/2012 2:00   -11.8             -13.1        90               13
# 8756  12/30/2012 20:00   -13.8             -16.5        80               24
#
#       Visibility_km  Press_kPa Weather_condition
# 67             25.0     101.74             Clear
# 114            25.0     100.71             Clear
# 115            25.0     100.80             Clear
# 116            25.0     100.83             Clear
# 117            25.0     100.83             Clear
# ...             ...        ...               ...
# 8646           25.0     102.47             Clear
# 8698           24.1     101.27             Clear
# 8713           25.0     101.31             Clear
# 8714           25.0     101.33             Clear
# 8756           25.0     101.52             Clear
#
# [1326 rows x 8 columns]

# %% [markdown]
# **Data Visualisation**

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data['Humidity'], bins=20, color='green', kde=True)
plt.xlabel('Humidity')
plt.ylabel('Frequency')
plt.title('Humidity Distribution')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=data['Wind Speed_km/h'], color='orange')
plt.xlabel('Wind Speed (km/h)')
plt.title('Wind Speed Distribution')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Temp_C', y='Dew Point Temp_C', data=data, color='purple')
plt.xlabel('Temperature (°C)')
plt.ylabel('Dew Point Temperature (°C)')
plt.title('Temperature vs. Dew Point Temperature')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Weather_condition', data=data, palette='viridis')
plt.xlabel('Weather Condition')
plt.ylabel('Count')
plt.title('Weather Condition Counts')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-15-4740d0427e53>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Weather_condition', data=data, palette='viridis')

# %% [markdown]
# **Time-Based Analysis**

# %%
# Convert 'Date/Time' column to datetime format
data['Date/Time'] = pd.to_datetime(data['Date/Time'])

# %%
# Extract and create new columns for Year, Month, Day, and Hour
data['Year'] = data['Date/Time'].dt.year
data['Month'] = data['Date/Time'].dt.month
data['Day'] = data['Date/Time'].dt.day
data['Hour'] = data['Date/Time'].dt.hour

# %%
# Plot average temperature over months
plt.figure(figsize=(12, 6))
sns.lineplot(x='Month', y='Temp_C', data=data.groupby('Month')['Temp_C'].mean().reset_index())
plt.title('Average Temperature Over Months')
plt.xlabel('Month')
plt.ylabel('Average Temperature (°C)')
plt.show()

#This plot can provide insights into the seasonal variations in temperature.It shows higher temperatures in summer months and lower temperatures in winter months.

# %% [markdown]
# **Correlation Analysis**

# %%
# Check the actual column names in the DataFrame
print(data.columns)

# Make sure the column name is correct and without leading/trailing whitespaces
column_name = 'Weather_condition'
if column_name in data.columns:
    data_encoded = pd.get_dummies(data, columns=[column_name])
    correlation_matrix = data_encoded.corr()
    print(correlation_matrix)
else:
    print(f"Column '{column_name}' not found in the DataFrame.")
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Humidity',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather_condition',
#        'Year', 'Month', 'Day', 'Hour'],
#       dtype='object')
#                                                       Temp_C  \
# Temp_C                                              1.000000
# Dew Point Temp_C                                    0.932714
# Humidity                                           -0.220182
# Wind Speed_km/h                                    -0.061876
# Visibility_km                                       0.273455
# Press_kPa                                          -0.236389
# Year                                                     NaN
# Month                                               0.218048
# Day                                                 0.009300
# Hour                                                0.106888
# Weather_condition_Clear                            -0.071162
# Weather_condition_Cloudy                           -0.035043
# Weather_condition_Drizzle                          -0.008464
# Weather_condition_Drizzle,Fog                      -0.005993
# Weather_condition_Drizzle,Ice Pellets,Fog          -0.007667
# Weather_condition_Drizzle,Snow                     -0.010005
# Weather_condition_Drizzle,Snow,Fog                 -0.028682
# Weather_condition_Fog                              -0.050692
# Weather_condition_Freezing Drizzle                 -0.034929
# Weather_condition_Freezing Drizzle,Fog             -0.025349
# Weather_condition_Freezing Drizzle,Haze            -0.022508
# Weather_condition_Freezing Drizzle,Snow            -0.042136
# Weather_condition_Freezing Fog                     -0.029902
# Weather_condition_Freezing Rain                    -0.043362
# Weather_condition_Freezing Rain,Fog                -0.020132
# Weather_condition_Freezing Rain,Haze               -0.017688
# Weather_condition_Freezing Rain,Ice Pellets,Fog    -0.010406
# Weather_condition_Freezing Rain,Snow Grains        -0.012598
# Weather_condition_Haze                             -0.032889
# Weather_condition_Mainly Clear                      0.180706
# Weather_condition_Moderate Rain,Fog                -0.006481
# Weather_condition_Moderate Snow                    -0.026158
# Weather_condition_Moderate Snow,Blowing Snow       -0.018398
# Weather_condition_Mostly Cloudy                     0.084358
# Weather_condition_Rain                              0.016063
# Weather_condition_Rain Showers                      0.062310
# Weather_condition_Rain Showers,Fog                  0.003654
# Weather_condition_Rain Showers,Snow Showers        -0.008584
# Weather_condition_Rain,Fog                         -0.005195
# Weather_condition_Rain,Haze                        -0.006587
# Weather_condition_Rain,Ice Pellets                 -0.007485
# Weather_condition_Rain,Snow                        -0.030020
# Weather_condition_Rain,Snow Grains                 -0.006298
# Weather_condition_Rain,Snow,Fog                    -0.007302
# Weather_condition_Rain,Snow,Ice Pellets            -0.014059
# Weather_condition_Snow                             -0.245705
# Weather_condition_Snow Pellets                     -0.007394
# Weather_condition_Snow Showers                     -0.087314
# Weather_condition_Snow Showers,Fog                 -0.035564
# Weather_condition_Snow,Blowing Snow                -0.056603
# Weather_condition_Snow,Fog                         -0.077207
# Weather_condition_Snow,Haze                        -0.026174
# Weather_condition_Snow,Ice Pellets                 -0.023895
# Weather_condition_Thunderstorms                     0.019823
# Weather_condition_Thunderstorms,Heavy Rain Showers  0.001919
# Weather_condition_Thunderstorms,Moderate Rain S...  0.009862
# Weather_condition_Thunderstorms,Rain                0.018401
# Weather_condition_Thunderstorms,Rain Showers        0.041081
# Weather_condition_Thunderstorms,Rain Showers,Fog    0.020247
# Weather_condition_Thunderstorms,Rain,Fog            0.010775
#
#                                                     Dew Point Temp_C  \
# Temp_C                                                      0.932714
# Dew Point Temp_C                                            1.000000
# Humidity                                                    0.139494
# Wind Speed_km/h                                            -0.095685
# Visibility_km                                               0.050813
# Press_kPa                                                  -0.320616
# Year                                                             NaN
# Month                                                       0.299641
# Day                                                         0.006390
# Hour                                                        0.017201
# Weather_condition_Clear                                    -0.095546
# Weather_condition_Cloudy                                   -0.008162
# Weather_condition_Drizzle                                   0.018561
# Weather_condition_Drizzle,Fog                               0.039454
# Weather_condition_Drizzle,Ice Pellets,Fog                  -0.003192
# Weather_condition_Drizzle,Snow                             -0.003335
# Weather_condition_Drizzle,Snow,Fog                         -0.009255
# Weather_condition_Fog                                       0.007316
# Weather_condition_Freezing Drizzle                         -0.027392
# Weather_condition_Freezing Drizzle,Fog                     -0.016189
# Weather_condition_Freezing Drizzle,Haze                    -0.017928
# Weather_condition_Freezing Drizzle,Snow                    -0.031328
# Weather_condition_Freezing Fog                             -0.023154
# Weather_condition_Freezing Rain                            -0.031699
# Weather_condition_Freezing Rain,Fog                        -0.012367
# Weather_condition_Freezing Rain,Haze                       -0.013875
# Weather_condition_Freezing Rain,Ice Pellets,Fog            -0.006133
# Weather_condition_Freezing Rain,Snow Grains                -0.009663
# Weather_condition_Haze                                     -0.021709
# Weather_condition_Mainly Clear                              0.104568
# Weather_condition_Moderate Rain,Fog                        -0.001721
# Weather_condition_Moderate Snow                            -0.019232
# Weather_condition_Moderate Snow,Blowing Snow               -0.012557
# Weather_condition_Mostly Cloudy                             0.029374
# Weather_condition_Rain                                      0.078342
# Weather_condition_Rain Showers                              0.090132
# Weather_condition_Rain Showers,Fog                          0.009359
# Weather_condition_Rain Showers,Snow Showers                -0.005624
# Weather_condition_Rain,Fog                                  0.049585
# Weather_condition_Rain,Haze                                -0.000830
# Weather_condition_Rain,Ice Pellets                         -0.003094
# Weather_condition_Rain,Snow                                -0.013000
# Weather_condition_Rain,Snow Grains                         -0.004565
# Weather_condition_Rain,Snow,Fog                            -0.002211
# Weather_condition_Rain,Snow,Ice Pellets                    -0.005355
# Weather_condition_Snow                                     -0.201609
# Weather_condition_Snow Pellets                             -0.008781
# Weather_condition_Snow Showers                             -0.079422
# Weather_condition_Snow Showers,Fog                         -0.028352
# Weather_condition_Snow,Blowing Snow                        -0.043538
# Weather_condition_Snow,Fog                                 -0.053311
# Weather_condition_Snow,Haze                                -0.020648
# Weather_condition_Snow,Ice Pellets                         -0.014948
# Weather_condition_Thunderstorms                             0.023844
# Weather_condition_Thunderstorms,Heavy Rain Showers          0.006319
# Weather_condition_Thunderstorms,Moderate Rain S...          0.015634
# Weather_condition_Thunderstorms,Rain                        0.027138
# Weather_condition_Thunderstorms,Rain Showers                0.059130
# Weather_condition_Thunderstorms,Rain Showers,Fog            0.027422
# Weather_condition_Thunderstorms,Rain,Fog                    0.015732
#
#                                                     Humidity  Wind Speed_km/h  \
# Temp_C                                             -0.220182        -0.061876
# Dew Point Temp_C                                    0.139494        -0.095685
# Humidity                                            1.000000        -0.092743
# Wind Speed_km/h                                    -0.092743         1.000000
# Visibility_km                                      -0.633683         0.004883
# Press_kPa                                          -0.231424        -0.356613
# Year                                                     NaN              NaN
# Month                                               0.232040        -0.030506
# Day                                                -0.010568         0.067770
# Hour                                               -0.243502         0.077594
# Weather_condition_Clear                            -0.073125        -0.212967
# Weather_condition_Cloudy                            0.063209         0.067317
# Weather_condition_Drizzle                           0.084243         0.009081
# Weather_condition_Drizzle,Fog                       0.146449        -0.034019
# Weather_condition_Drizzle,Ice Pellets,Fog           0.015496         0.006208
# Weather_condition_Drizzle,Snow                      0.023253        -0.001642
# Weather_condition_Drizzle,Snow,Fog                  0.069515         0.002798
# Weather_condition_Fog                               0.193645        -0.106178
# Weather_condition_Freezing Drizzle                  0.026942         0.005285
# Weather_condition_Freezing Drizzle,Fog              0.032558         0.006182
# Weather_condition_Freezing Drizzle,Haze             0.015917        -0.009812
# Weather_condition_Freezing Drizzle,Snow             0.039054         0.005409
# Weather_condition_Freezing Fog                      0.025634        -0.025047
# Weather_condition_Freezing Rain                     0.040647         0.019631
# Weather_condition_Freezing Rain,Fog                 0.027842         0.001362
# Weather_condition_Freezing Rain,Haze                0.013441        -0.012932
# Weather_condition_Freezing Rain,Ice Pellets,Fog     0.015496         0.016033
# Weather_condition_Freezing Rain,Snow Grains         0.010450         0.020945
# Weather_condition_Haze                              0.035838        -0.022165
# Weather_condition_Mainly Clear                     -0.224542        -0.051751
# Weather_condition_Moderate Rain,Fog                 0.016757         0.002523
# Weather_condition_Moderate Snow                     0.025634         0.046197
# Weather_condition_Moderate Snow,Blowing Snow        0.022361         0.043519
# Weather_condition_Mostly Cloudy                    -0.174854         0.055485
# Weather_condition_Rain                              0.181836         0.094233
# Weather_condition_Rain Showers                      0.067553         0.037235
# Weather_condition_Rain Showers,Fog                  0.018018        -0.002389
# Weather_condition_Rain Showers,Snow Showers         0.008089         0.013122
# Weather_condition_Rain,Fog                          0.176130        -0.002029
# Weather_condition_Rain,Haze                         0.017373        -0.006975
# Weather_condition_Rain,Ice Pellets                  0.015496         0.011120
# Weather_condition_Rain,Snow                         0.057770         0.070116
# Weather_condition_Rain,Snow Grains                  0.004773         0.013577
# Weather_condition_Rain,Snow,Fog                     0.018018        -0.007302
# Weather_condition_Rain,Snow,Ice Pellets             0.030366         0.020402
# Weather_condition_Snow                              0.151311         0.126355
# Weather_condition_Snow Pellets                     -0.005318         0.024630
# Weather_condition_Snow Showers                      0.024109         0.040929
# Weather_condition_Snow Showers,Fog                  0.029419        -0.002937
# Weather_condition_Snow,Blowing Snow                 0.046900         0.106623
# Weather_condition_Snow,Fog                          0.089358         0.017808
# Weather_condition_Snow,Haze                         0.018576        -0.027319
# Weather_condition_Snow,Ice Pellets                  0.031270         0.026745
# Weather_condition_Thunderstorms                     0.008535        -0.012932
# Weather_condition_Thunderstorms,Heavy Rain Showers  0.012973        -0.007302
# Weather_condition_Thunderstorms,Moderate Rain S...  0.016126         0.000067
# Weather_condition_Thunderstorms,Rain                0.023564         0.001534
# Weather_condition_Thunderstorms,Rain Showers        0.047832         0.016555
# Weather_condition_Thunderstorms,Rain Showers,Fog    0.018102         0.010044
# Weather_condition_Thunderstorms,Rain,Fog            0.012973         0.004980
#
#                                                     Visibility_km  Press_kPa  \
# Temp_C                                                   0.273455  -0.236389
# Dew Point Temp_C                                         0.050813  -0.320616
# Humidity                                                -0.633683  -0.231424
# Wind Speed_km/h                                          0.004883  -0.356613
# Visibility_km                                            1.000000   0.231847
# Press_kPa                                                0.231847   1.000000
# Year                                                          NaN        NaN
# Month                                                   -0.027314   0.070355
# Day                                                      0.033651  -0.002481
# Hour                                                     0.064385  -0.030344
# Weather_condition_Clear                                  0.083142   0.267707
# Weather_condition_Cloudy                                -0.040724  -0.082199
# Weather_condition_Drizzle                               -0.052804  -0.050004
# Weather_condition_Drizzle,Fog                           -0.170193  -0.030103
# Weather_condition_Drizzle,Ice Pellets,Fog               -0.020005  -0.003308
# Weather_condition_Drizzle,Snow                          -0.020522  -0.002890
# Weather_condition_Drizzle,Snow,Fog                      -0.072584  -0.086755
# Weather_condition_Fog                                   -0.223645   0.020685
# Weather_condition_Freezing Drizzle                      -0.041313  -0.028402
# Weather_condition_Freezing Drizzle,Fog                  -0.046393  -0.018895
# Weather_condition_Freezing Drizzle,Haze                 -0.036607  -0.016096
# Weather_condition_Freezing Drizzle,Snow                 -0.061135  -0.022267
# Weather_condition_Freezing Fog                          -0.045683   0.032078
# Weather_condition_Freezing Rain                         -0.061478  -0.066491
# Weather_condition_Freezing Rain,Fog                     -0.034014  -0.027987
# Weather_condition_Freezing Rain,Haze                    -0.030207  -0.012099
# Weather_condition_Freezing Rain,Ice Pellets,Fog         -0.016624  -0.001285
# Weather_condition_Freezing Rain,Snow Grains             -0.019329  -0.031502
# Weather_condition_Haze                                  -0.067124   0.021809
# Weather_condition_Mainly Clear                           0.293664   0.131223
# Weather_condition_Moderate Rain,Fog                     -0.017977  -0.013549
# Weather_condition_Moderate Snow                         -0.045514  -0.019641
# Weather_condition_Moderate Snow,Blowing Snow            -0.032359  -0.008612
# Weather_condition_Mostly Cloudy                          0.157852  -0.017321
# Weather_condition_Rain                                  -0.132574  -0.184205
# Weather_condition_Rain Showers                          -0.056802  -0.113476
# Weather_condition_Rain Showers,Fog                      -0.017977  -0.015445
# Weather_condition_Rain Showers,Snow Showers             -0.007131   0.000865
# Weather_condition_Rain,Fog                              -0.190555  -0.075494
# Weather_condition_Rain,Haze                             -0.030700  -0.011205
# Weather_condition_Rain,Ice Pellets                      -0.015187  -0.011779
# Weather_condition_Rain,Snow                             -0.057414  -0.059089
# Weather_condition_Rain,Snow Grains                      -0.002252  -0.005710
# Weather_condition_Rain,Snow,Fog                         -0.017977  -0.004066
# Weather_condition_Rain,Snow,Ice Pellets                 -0.036636  -0.023941
# Weather_condition_Snow                                  -0.281651  -0.131666
# Weather_condition_Snow Pellets                          -0.021358  -0.017089
# Weather_condition_Snow Showers                          -0.049318  -0.008659
# Weather_condition_Snow Showers,Fog                      -0.034902   0.006092
# Weather_condition_Snow,Blowing Snow                     -0.086903  -0.074304
# Weather_condition_Snow,Fog                              -0.119167  -0.027972
# Weather_condition_Snow,Haze                             -0.043534  -0.007624
# Weather_condition_Snow,Ice Pellets                      -0.041940  -0.015591
# Weather_condition_Thunderstorms                         -0.003724  -0.014692
# Weather_condition_Thunderstorms,Heavy Rain Showers      -0.021358  -0.010009
# Weather_condition_Thunderstorms,Moderate Rain S...      -0.020682  -0.013169
# Weather_condition_Thunderstorms,Rain                    -0.011468  -0.013833
# Weather_condition_Thunderstorms,Rain Showers            -0.039837  -0.041398
# Weather_condition_Thunderstorms,Rain Showers,Fog        -0.026307  -0.021645
# Weather_condition_Thunderstorms,Rain,Fog                -0.019329  -0.012284
#
#                                                     Year         Month  \
# Temp_C                                               NaN  2.180482e-01
# Dew Point Temp_C                                     NaN  2.996407e-01
# Humidity                                             NaN  2.320402e-01
# Wind Speed_km/h                                      NaN -3.050612e-02
# Visibility_km                                        NaN -2.731366e-02
# Press_kPa                                            NaN  7.035525e-02
# Year                                                 NaN           NaN
# Month                                                NaN  1.000000e+00
# Day                                                  NaN  6.443300e-03
# Hour                                                 NaN  2.574200e-15
# Weather_condition_Clear                              NaN -2.709939e-02
# Weather_condition_Cloudy                             NaN  1.986083e-04
# Weather_condition_Drizzle                            NaN  5.078600e-02
# Weather_condition_Drizzle,Fog                        NaN  1.356676e-03
# Weather_condition_Drizzle,Ice Pellets,Fog            NaN  1.696238e-02
# Weather_condition_Drizzle,Snow                       NaN  2.398979e-02
# Weather_condition_Drizzle,Snow,Fog                   NaN  6.574744e-02
# Weather_condition_Fog                                NaN -5.104704e-03
# Weather_condition_Freezing Drizzle                   NaN -2.992053e-02
# Weather_condition_Freezing Drizzle,Fog               NaN -1.399165e-02
# Weather_condition_Freezing Drizzle,Haze              NaN -2.417370e-02
# Weather_condition_Freezing Drizzle,Snow              NaN -3.404713e-03
# Weather_condition_Freezing Fog                       NaN -2.636884e-02
# Weather_condition_Freezing Rain                      NaN -5.142699e-02
# Weather_condition_Freezing Rain,Fog                  NaN -8.448843e-05
# Weather_condition_Freezing Rain,Haze                 NaN -1.973662e-02
# Weather_condition_Freezing Rain,Ice Pellets,Fog      NaN  1.696238e-02
# Weather_condition_Freezing Rain,Snow Grains          NaN -1.704685e-02
# Weather_condition_Haze                               NaN -1.022587e-02
# Weather_condition_Mainly Clear                       NaN  5.240225e-02
# Weather_condition_Moderate Rain,Fog                  NaN  1.696238e-02
# Weather_condition_Moderate Snow                      NaN -8.448843e-05
# Weather_condition_Moderate Snow,Blowing Snow         NaN  2.398979e-02
# Weather_condition_Mostly Cloudy                      NaN -2.391551e-03
# Weather_condition_Rain                               NaN  3.745347e-03
# Weather_condition_Rain Showers                       NaN  1.833267e-02
# Weather_condition_Rain Showers,Fog                   NaN  1.077888e-02
# Weather_condition_Rain Showers,Snow Showers          NaN  2.180347e-02
# Weather_condition_Rain,Fog                           NaN  5.357753e-02
# Weather_condition_Rain,Haze                          NaN -1.881803e-02
# Weather_condition_Rain,Ice Pellets                   NaN  1.696238e-02
# Weather_condition_Rain,Snow                          NaN  6.385575e-03
# Weather_condition_Rain,Snow Grains                   NaN  1.696238e-02
# Weather_condition_Rain,Snow,Fog                      NaN  1.696238e-02
# Weather_condition_Rain,Snow,Ice Pellets              NaN  3.393056e-02
# Weather_condition_Snow                               NaN -1.525089e-01
# Weather_condition_Snow Pellets                       NaN  1.387063e-02
# Weather_condition_Snow Showers                       NaN  1.569135e-02
# Weather_condition_Snow Showers,Fog                   NaN  3.393056e-02
# Weather_condition_Snow,Blowing Snow                  NaN  1.366117e-02
# Weather_condition_Snow,Fog                           NaN  6.468152e-02
# Weather_condition_Snow,Haze                          NaN -3.121167e-02
# Weather_condition_Snow,Ice Pellets                   NaN  1.883492e-02
# Weather_condition_Thunderstorms                      NaN  2.126585e-03
# Weather_condition_Thunderstorms,Heavy Rain Showers   NaN -4.679860e-03
# Weather_condition_Thunderstorms,Moderate Rain S...   NaN  1.503637e-03
# Weather_condition_Thunderstorms,Rain                 NaN -9.657775e-04
# Weather_condition_Thunderstorms,Rain Showers         NaN  5.246094e-03
# Weather_condition_Thunderstorms,Rain Showers,Fog     NaN  8.194476e-04
# Weather_condition_Thunderstorms,Rain,Fog             NaN  1.503637e-03
#
#                                                              Day  \
# Temp_C                                              9.299991e-03
# Dew Point Temp_C                                    6.390196e-03
# Humidity                                           -1.056844e-02
# Wind Speed_km/h                                     6.777025e-02
# Visibility_km                                       3.365052e-02
# Press_kPa                                          -2.481106e-03
# Year                                                         NaN
# Month                                               6.443300e-03
# Day                                                 1.000000e+00
# Hour                                                1.429094e-16
# Weather_condition_Clear                             2.780392e-02
# Weather_condition_Cloudy                           -1.874672e-02
# Weather_condition_Drizzle                          -5.123579e-03
# Weather_condition_Drizzle,Fog                      -3.557076e-02
# Weather_condition_Drizzle,Ice Pellets,Fog           1.505420e-03
# Weather_condition_Drizzle,Snow                      3.841750e-03
# Weather_condition_Drizzle,Snow,Fog                  1.772593e-02
# Weather_condition_Fog                              -4.213559e-02
# Weather_condition_Freezing Drizzle                 -2.165547e-02
# Weather_condition_Freezing Drizzle,Fog             -1.905891e-02
# Weather_condition_Freezing Drizzle,Haze            -3.095497e-02
# Weather_condition_Freezing Drizzle,Snow             2.253131e-02
# Weather_condition_Freezing Fog                     -1.227706e-03
# Weather_condition_Freezing Rain                    -1.768246e-02
# Weather_condition_Freezing Rain,Fog                -7.283505e-03
# Weather_condition_Freezing Rain,Haze               -2.527319e-02
# Weather_condition_Freezing Rain,Ice Pellets,Fog     1.505420e-03
# Weather_condition_Freezing Rain,Snow Grains        -3.338392e-03
# Weather_condition_Haze                             -4.275073e-03
# Weather_condition_Mainly Clear                      3.344288e-02
# Weather_condition_Moderate Rain,Fog                -6.971251e-03
# Weather_condition_Moderate Snow                     9.067152e-03
# Weather_condition_Moderate Snow,Blowing Snow        1.925554e-02
# Weather_condition_Mostly Cloudy                    -5.994495e-03
# Weather_condition_Rain                             -3.844216e-02
# Weather_condition_Rain Showers                     -3.417752e-03
# Weather_condition_Rain Showers,Fog                  5.138278e-03
# Weather_condition_Rain Showers,Snow Showers        -1.927894e-02
# Weather_condition_Rain,Fog                         -3.200574e-02
# Weather_condition_Rain,Haze                        -5.782923e-03
# Weather_condition_Rain,Ice Pellets                  2.716372e-03
# Weather_condition_Rain,Snow                         2.724932e-02
# Weather_condition_Rain,Snow Grains                  6.349231e-03
# Weather_condition_Rain,Snow,Fog                    -9.393157e-03
# Weather_condition_Rain,Snow,Ice Pellets             1.270063e-02
# Weather_condition_Snow                              3.033361e-04
# Weather_condition_Snow Pellets                      9.982090e-03
# Weather_condition_Snow Showers                     -2.887787e-03
# Weather_condition_Snow Showers,Fog                  3.026245e-02
# Weather_condition_Snow,Blowing Snow                 3.493458e-02
# Weather_condition_Snow,Fog                          5.186651e-02
# Weather_condition_Snow,Haze                        -3.996725e-02
# Weather_condition_Snow,Ice Pellets                 -1.256542e-03
# Weather_condition_Thunderstorms                    -9.859399e-03
# Weather_condition_Thunderstorms,Heavy Rain Showers  1.603685e-02
# Weather_condition_Thunderstorms,Moderate Rain S...  1.505420e-03
# Weather_condition_Thunderstorms,Rain                1.659223e-02
# Weather_condition_Thunderstorms,Rain Showers        1.905570e-02
# Weather_condition_Thunderstorms,Rain Showers,Fog    2.078757e-02
# Weather_condition_Thunderstorms,Rain,Fog            1.505420e-03
#
#                                                             Hour  ...  \
# Temp_C                                              1.068878e-01  ...
# Dew Point Temp_C                                    1.720132e-02  ...
# Humidity                                           -2.435021e-01  ...
# Wind Speed_km/h                                     7.759403e-02  ...
# Visibility_km                                       6.438479e-02  ...
# Press_kPa                                          -3.034413e-02  ...
# Year                                                         NaN  ...
# Month                                               2.574200e-15  ...
# Day                                                 1.429094e-16  ...
# Hour                                                1.000000e+00  ...
# Weather_condition_Clear                            -8.700691e-02  ...
# Weather_condition_Cloudy                            4.757769e-03  ...
# Weather_condition_Drizzle                           2.304294e-02  ...
# Weather_condition_Drizzle,Fog                       1.713908e-02  ...
# Weather_condition_Drizzle,Ice Pellets,Fog          -3.853677e-03  ...
# Weather_condition_Drizzle,Snow                      1.090046e-02  ...
# Weather_condition_Drizzle,Snow,Fog                 -2.011534e-02  ...
# Weather_condition_Fog                              -4.811099e-02  ...
# Weather_condition_Freezing Drizzle                 -2.127294e-02  ...
# Weather_condition_Freezing Drizzle,Fog             -1.951394e-02  ...
# Weather_condition_Freezing Drizzle,Haze             1.335105e-03  ...
# Weather_condition_Freezing Drizzle,Snow            -5.812946e-03  ...
# Weather_condition_Freezing Fog                     -1.464647e-02  ...
# Weather_condition_Freezing Rain                    -7.833331e-03  ...
# Weather_condition_Freezing Rain,Fog                -5.396069e-03  ...
# Weather_condition_Freezing Rain,Haze                6.540278e-03  ...
# Weather_condition_Freezing Rain,Ice Pellets,Fog    -1.310250e-02  ...
# Weather_condition_Freezing Rain,Snow Grains        -3.853677e-03  ...
# Weather_condition_Haze                              1.619928e-02  ...
# Weather_condition_Mainly Clear                      2.384487e-02  ...
# Weather_condition_Moderate Rain,Fog                -5.395147e-03  ...
# Weather_condition_Moderate Snow                     1.541734e-03  ...
# Weather_condition_Moderate Snow,Blowing Snow       -1.090046e-03  ...
# Weather_condition_Mostly Cloudy                     4.586926e-02  ...
# Weather_condition_Rain                              9.596946e-03  ...
# Weather_condition_Rain Showers                      3.977385e-03  ...
# Weather_condition_Rain Showers,Fog                 -1.310250e-02  ...
# Weather_condition_Rain Showers,Snow Showers        -5.450232e-03  ...
# Weather_condition_Rain,Fog                          1.772039e-02  ...
# Weather_condition_Rain,Haze                        -9.345733e-03  ...
# Weather_condition_Rain,Ice Pellets                 -1.001956e-02  ...
# Weather_condition_Rain,Snow                        -2.909442e-02  ...
# Weather_condition_Rain,Snow Grains                 -1.772691e-02  ...
# Weather_condition_Rain,Snow,Fog                     1.464397e-02  ...
# Weather_condition_Rain,Snow,Ice Pellets            -2.543861e-02  ...
# Weather_condition_Snow                             -2.395307e-03  ...
# Weather_condition_Snow Pellets                      5.395147e-03  ...
# Weather_condition_Snow Showers                      1.417691e-02  ...
# Weather_condition_Snow Showers,Fog                 -7.708670e-04  ...
# Weather_condition_Snow,Blowing Snow                 7.965012e-03  ...
# Weather_condition_Snow,Fog                          1.561714e-02  ...
# Weather_condition_Snow,Haze                         2.585714e-02  ...
# Weather_condition_Snow,Ice Pellets                 -2.454980e-02  ...
# Weather_condition_Thunderstorms                    -6.540278e-03  ...
# Weather_condition_Thunderstorms,Heavy Rain Showers -8.478089e-03  ...
# Weather_condition_Thunderstorms,Moderate Rain S... -8.478089e-03  ...
# Weather_condition_Thunderstorms,Rain                1.824643e-02  ...
# Weather_condition_Thunderstorms,Rain Showers        2.044195e-02  ...
# Weather_condition_Thunderstorms,Rain Showers,Fog   -2.225175e-03  ...
# Weather_condition_Thunderstorms,Rain,Fog           -1.001956e-02  ...
#
#                                                     Weather_condition_Snow,Fog  \
# Temp_C                                                               -0.077207
# Dew Point Temp_C                                                     -0.053311
# Humidity                                                              0.089358
# Wind Speed_km/h                                                       0.017808
# Visibility_km                                                        -0.119167
# Press_kPa                                                            -0.027972
# Year                                                                       NaN
# Month                                                                 0.064682
# Day                                                                   0.051867
# Hour                                                                  0.015617
# Weather_condition_Clear                                              -0.027424
# Weather_condition_Cloudy                                             -0.032186
# Weather_condition_Drizzle                                            -0.004454
# Weather_condition_Drizzle,Fog                                        -0.006235
# Weather_condition_Drizzle,Ice Pellets,Fog                            -0.000694
# Weather_condition_Drizzle,Snow                                       -0.000981
# Weather_condition_Drizzle,Snow,Fog                                   -0.002690
# Weather_condition_Fog                                                -0.008573
# Weather_condition_Freezing Drizzle                                   -0.001837
# Weather_condition_Freezing Drizzle,Fog                               -0.001700
# Weather_condition_Freezing Drizzle,Haze                              -0.001202
# Weather_condition_Freezing Drizzle,Snow                              -0.002303
# Weather_condition_Freezing Fog                                       -0.001388
# Weather_condition_Freezing Rain                                      -0.002599
# Weather_condition_Freezing Rain,Fog                                  -0.001388
# Weather_condition_Freezing Rain,Haze                                 -0.000981
# Weather_condition_Freezing Rain,Ice Pellets,Fog                      -0.000694
# Weather_condition_Freezing Rain,Snow Grains                          -0.000694
# Weather_condition_Haze                                               -0.002778
# Weather_condition_Mainly Clear                                       -0.036524
# Weather_condition_Moderate Rain,Fog                                  -0.000694
# Weather_condition_Moderate Snow                                      -0.001388
# Weather_condition_Moderate Snow,Blowing Snow                         -0.000981
# Weather_condition_Mostly Cloudy                                      -0.036102
# Weather_condition_Rain                                               -0.012356
# Weather_condition_Rain Showers                                       -0.009618
# Weather_condition_Rain Showers,Fog                                   -0.000694
# Weather_condition_Rain Showers,Snow Showers                          -0.000981
# Weather_condition_Rain,Fog                                           -0.007524
# Weather_condition_Rain,Haze                                          -0.001202
# Weather_condition_Rain,Ice Pellets                                   -0.000694
# Weather_condition_Rain,Snow                                          -0.002947
# Weather_condition_Rain,Snow Grains                                   -0.000694
# Weather_condition_Rain,Snow,Fog                                      -0.000694
# Weather_condition_Rain,Snow,Ice Pellets                              -0.001388
# Weather_condition_Snow                                               -0.014019
# Weather_condition_Snow Pellets                                       -0.000694
# Weather_condition_Snow Showers                                       -0.005394
# Weather_condition_Snow Showers,Fog                                   -0.001388
# Weather_condition_Snow,Blowing Snow                                  -0.003028
# Weather_condition_Snow,Fog                                            1.000000
# Weather_condition_Snow,Haze                                          -0.001552
# Weather_condition_Snow,Ice Pellets                                   -0.001700
# Weather_condition_Thunderstorms                                      -0.000981
# Weather_condition_Thunderstorms,Heavy Rain Showers                   -0.000694
# Weather_condition_Thunderstorms,Moderate Rain S...                   -0.000694
# Weather_condition_Thunderstorms,Rain                                 -0.001202
# Weather_condition_Thunderstorms,Rain Showers                         -0.002778
# Weather_condition_Thunderstorms,Rain Showers,Fog                     -0.001202
# Weather_condition_Thunderstorms,Rain,Fog                             -0.000694
#
#                                                     Weather_condition_Snow,Haze  \
# Temp_C                                                                -0.026174
# Dew Point Temp_C                                                      -0.020648
# Humidity                                                               0.018576
# Wind Speed_km/h                                                       -0.027319
# Visibility_km                                                         -0.043534
# Press_kPa                                                             -0.007624
# Year                                                                        NaN
# Month                                                                 -0.031212
# Day                                                                   -0.039967
# Hour                                                                   0.025857
# Weather_condition_Clear                                               -0.010063
# Weather_condition_Cloudy                                              -0.011810
# Weather_condition_Drizzle                                             -0.001634
# Weather_condition_Drizzle,Fog                                         -0.002288
# Weather_condition_Drizzle,Ice Pellets,Fog                             -0.000255
# Weather_condition_Drizzle,Snow                                        -0.000360
# Weather_condition_Drizzle,Snow,Fog                                    -0.000987
# Weather_condition_Fog                                                 -0.003146
# Weather_condition_Freezing Drizzle                                    -0.000674
# Weather_condition_Freezing Drizzle,Fog                                -0.000624
# Weather_condition_Freezing Drizzle,Haze                               -0.000441
# Weather_condition_Freezing Drizzle,Snow                               -0.000845
# Weather_condition_Freezing Fog                                        -0.000509
# Weather_condition_Freezing Rain                                       -0.000954
# Weather_condition_Freezing Rain,Fog                                   -0.000509
# Weather_condition_Freezing Rain,Haze                                  -0.000360
# Weather_condition_Freezing Rain,Ice Pellets,Fog                       -0.000255
# Weather_condition_Freezing Rain,Snow Grains                           -0.000255
# Weather_condition_Haze                                                -0.001019
# Weather_condition_Mainly Clear                                        -0.013402
# Weather_condition_Moderate Rain,Fog                                   -0.000255
# Weather_condition_Moderate Snow                                       -0.000509
# Weather_condition_Moderate Snow,Blowing Snow                          -0.000360
# Weather_condition_Mostly Cloudy                                       -0.013247
# Weather_condition_Rain                                                -0.004534
# Weather_condition_Rain Showers                                        -0.003529
# Weather_condition_Rain Showers,Fog                                    -0.000255
# Weather_condition_Rain Showers,Snow Showers                           -0.000360
# Weather_condition_Rain,Fog                                            -0.002761
# Weather_condition_Rain,Haze                                           -0.000441
# Weather_condition_Rain,Ice Pellets                                    -0.000255
# Weather_condition_Rain,Snow                                           -0.001081
# Weather_condition_Rain,Snow Grains                                    -0.000255
# Weather_condition_Rain,Snow,Fog                                       -0.000255
# Weather_condition_Rain,Snow,Ice Pellets                               -0.000509
# Weather_condition_Snow                                                -0.005144
# Weather_condition_Snow Pellets                                        -0.000255
# Weather_condition_Snow Showers                                        -0.001979
# Weather_condition_Snow Showers,Fog                                    -0.000509
# Weather_condition_Snow,Blowing Snow                                   -0.001111
# Weather_condition_Snow,Fog                                            -0.001552
# Weather_condition_Snow,Haze                                            1.000000
# Weather_condition_Snow,Ice Pellets                                    -0.000624
# Weather_condition_Thunderstorms                                       -0.000360
# Weather_condition_Thunderstorms,Heavy Rain Showers                    -0.000255
# Weather_condition_Thunderstorms,Moderate Rain S...                    -0.000255
# Weather_condition_Thunderstorms,Rain                                  -0.000441
# Weather_condition_Thunderstorms,Rain Showers                          -0.001019
# Weather_condition_Thunderstorms,Rain Showers,Fog                      -0.000441
# Weather_condition_Thunderstorms,Rain,Fog                              -0.000255
#
#                                                     Weather_condition_Snow,Ice Pellets  \
# Temp_C                                                                       -0.023895
# Dew Point Temp_C                                                             -0.014948
# Humidity                                                                      0.031270
# Wind Speed_km/h                                                               0.026745
# Visibility_km                                                                -0.041940
# Press_kPa                                                                    -0.015591
# Year                                                                               NaN
# Month                                                                         0.018835
# Day                                                                          -0.001257
# Hour                                                                         -0.024550
# Weather_condition_Clear                                                      -0.011024
# Weather_condition_Cloudy                                                     -0.012938
# Weather_condition_Drizzle                                                    -0.001790
# Weather_condition_Drizzle,Fog                                                -0.002506
# Weather_condition_Drizzle,Ice Pellets,Fog                                    -0.000279
# Weather_condition_Drizzle,Snow                                               -0.000395
# Weather_condition_Drizzle,Snow,Fog                                           -0.001081
# Weather_condition_Fog                                                        -0.003446
# Weather_condition_Freezing Drizzle                                           -0.000738
# Weather_condition_Freezing Drizzle,Fog                                       -0.000684
# Weather_condition_Freezing Drizzle,Haze                                      -0.000483
# Weather_condition_Freezing Drizzle,Snow                                      -0.000926
# Weather_condition_Freezing Fog                                               -0.000558
# Weather_condition_Freezing Rain                                              -0.001045
# Weather_condition_Freezing Rain,Fog                                          -0.000558
# Weather_condition_Freezing Rain,Haze                                         -0.000395
# Weather_condition_Freezing Rain,Ice Pellets,Fog                              -0.000279
# Weather_condition_Freezing Rain,Snow Grains                                  -0.000279
# Weather_condition_Haze                                                       -0.001117
# Weather_condition_Mainly Clear                                               -0.014682
# Weather_condition_Moderate Rain,Fog                                          -0.000279
# Weather_condition_Moderate Snow                                              -0.000558
# Weather_condition_Moderate Snow,Blowing Snow                                 -0.000395
# Weather_condition_Mostly Cloudy                                              -0.014512
# Weather_condition_Rain                                                       -0.004967
# Weather_condition_Rain Showers                                               -0.003866
# Weather_condition_Rain Showers,Fog                                           -0.000279
# Weather_condition_Rain Showers,Snow Showers                                  -0.000395
# Weather_condition_Rain,Fog                                                   -0.003024
# Weather_condition_Rain,Haze                                                  -0.000483
# Weather_condition_Rain,Ice Pellets                                           -0.000279
# Weather_condition_Rain,Snow                                                  -0.001185
# Weather_condition_Rain,Snow Grains                                           -0.000279
# Weather_condition_Rain,Snow,Fog                                              -0.000279
# Weather_condition_Rain,Snow,Ice Pellets                                      -0.000558
# Weather_condition_Snow                                                       -0.005635
# Weather_condition_Snow Pellets                                               -0.000279
# Weather_condition_Snow Showers                                               -0.002168
# Weather_condition_Snow Showers,Fog                                           -0.000558
# Weather_condition_Snow,Blowing Snow                                          -0.001217
# Weather_condition_Snow,Fog                                                   -0.001700
# Weather_condition_Snow,Haze                                                  -0.000624
# Weather_condition_Snow,Ice Pellets                                            1.000000
# Weather_condition_Thunderstorms                                              -0.000395
# Weather_condition_Thunderstorms,Heavy Rain Showers                           -0.000279
# Weather_condition_Thunderstorms,Moderate Rain S...                           -0.000279
# Weather_condition_Thunderstorms,Rain                                         -0.000483
# Weather_condition_Thunderstorms,Rain Showers                                 -0.001117
# Weather_condition_Thunderstorms,Rain Showers,Fog                             -0.000483
# Weather_condition_Thunderstorms,Rain,Fog                                     -0.000279
#
#                                                     Weather_condition_Thunderstorms  \
# Temp_C                                                                     0.019823
# Dew Point Temp_C                                                           0.023844
# Humidity                                                                   0.008535
# Wind Speed_km/h                                                           -0.012932
# Visibility_km                                                             -0.003724
# Press_kPa                                                                 -0.014692
# Year                                                                            NaN
# Month                                                                      0.002127
# Day                                                                       -0.009859
# Hour                                                                      -0.006540
# ...
# Weather_condition_Freezing Rain,Haze                                                   -0.000645
# Weather_condition_Freezing Rain,Ice Pellets,Fog                                        -0.000456
# Weather_condition_Freezing Rain,Snow Grains                                            -0.000456
# Weather_condition_Haze                                                                 -0.001825
# Weather_condition_Mainly Clear                                                         -0.023989
# Weather_condition_Moderate Rain,Fog                                                    -0.000456
# Weather_condition_Moderate Snow                                                        -0.000912
# Weather_condition_Moderate Snow,Blowing Snow                                           -0.000645
# Weather_condition_Mostly Cloudy                                                        -0.023712
# Weather_condition_Rain                                                                 -0.008116
# Weather_condition_Rain Showers                                                         -0.006317
# Weather_condition_Rain Showers,Fog                                                     -0.000456
# Weather_condition_Rain Showers,Snow Showers                                            -0.000645
# Weather_condition_Rain,Fog                                                             -0.004942
# Weather_condition_Rain,Haze                                                            -0.000790
# Weather_condition_Rain,Ice Pellets                                                     -0.000456
# Weather_condition_Rain,Snow                                                            -0.001936
# Weather_condition_Rain,Snow Grains                                                     -0.000456
# Weather_condition_Rain,Snow,Fog                                                        -0.000456
# Weather_condition_Rain,Snow,Ice Pellets                                                -0.000912
# Weather_condition_Snow                                                                 -0.009208
# Weather_condition_Snow Pellets                                                         -0.000456
# Weather_condition_Snow Showers                                                         -0.003543
# Weather_condition_Snow Showers,Fog                                                     -0.000912
# Weather_condition_Snow,Blowing Snow                                                    -0.001989
# Weather_condition_Snow,Fog                                                             -0.002778
# Weather_condition_Snow,Haze                                                            -0.001019
# Weather_condition_Snow,Ice Pellets                                                     -0.001117
# Weather_condition_Thunderstorms                                                        -0.000645
# Weather_condition_Thunderstorms,Heavy Rain Showers                                     -0.000456
# Weather_condition_Thunderstorms,Moderate Rain S...                                     -0.000456
# Weather_condition_Thunderstorms,Rain                                                   -0.000790
# Weather_condition_Thunderstorms,Rain Showers                                            1.000000
# Weather_condition_Thunderstorms,Rain Showers,Fog                                       -0.000790
# Weather_condition_Thunderstorms,Rain,Fog                                               -0.000456
#
#                                                     Weather_condition_Thunderstorms,Rain Showers,Fog  \
# Temp_C                                                                                      0.020247
# Dew Point Temp_C                                                                            0.027422
# Humidity                                                                                    0.018102
# Wind Speed_km/h                                                                             0.010044
# Visibility_km                                                                              -0.026307
# Press_kPa                                                                                  -0.021645
# Year                                                                                             NaN
# Month                                                                                       0.000819
# Day                                                                                         0.020788
# Hour                                                                                       -0.002225
# Weather_condition_Clear                                                                    -0.007794
# Weather_condition_Cloudy                                                                   -0.009147
# Weather_condition_Drizzle                                                                  -0.001266
# Weather_condition_Drizzle,Fog                                                              -0.001772
# Weather_condition_Drizzle,Ice Pellets,Fog                                                  -0.000197
# Weather_condition_Drizzle,Snow                                                             -0.000279
# Weather_condition_Drizzle,Snow,Fog                                                         -0.000764
# Weather_condition_Fog                                                                      -0.002436
# Weather_condition_Freezing Drizzle                                                         -0.000522
# Weather_condition_Freezing Drizzle,Fog                                                     -0.000483
# Weather_condition_Freezing Drizzle,Haze                                                    -0.000342
# Weather_condition_Freezing Drizzle,Snow                                                    -0.000655
# Weather_condition_Freezing Fog                                                             -0.000395
# Weather_condition_Freezing Rain                                                            -0.000739
# Weather_condition_Freezing Rain,Fog                                                        -0.000395
# Weather_condition_Freezing Rain,Haze                                                       -0.000279
# Weather_condition_Freezing Rain,Ice Pellets,Fog                                            -0.000197
# Weather_condition_Freezing Rain,Snow Grains                                                -0.000197
# Weather_condition_Haze                                                                     -0.000790
# Weather_condition_Mainly Clear                                                             -0.010380
# Weather_condition_Moderate Rain,Fog                                                        -0.000197
# Weather_condition_Moderate Snow                                                            -0.000395
# Weather_condition_Moderate Snow,Blowing Snow                                               -0.000279
# Weather_condition_Mostly Cloudy                                                            -0.010260
# Weather_condition_Rain                                                                     -0.003512
# Weather_condition_Rain Showers                                                             -0.002734
# Weather_condition_Rain Showers,Fog                                                         -0.000197
# Weather_condition_Rain Showers,Snow Showers                                                -0.000279
# Weather_condition_Rain,Fog                                                                 -0.002138
# Weather_condition_Rain,Haze                                                                -0.000342
# Weather_condition_Rain,Ice Pellets                                                         -0.000197
# Weather_condition_Rain,Snow                                                                -0.000838
# Weather_condition_Rain,Snow Grains                                                         -0.000197
# Weather_condition_Rain,Snow,Fog                                                            -0.000197
# Weather_condition_Rain,Snow,Ice Pellets                                                    -0.000395
# Weather_condition_Snow                                                                     -0.003984
# Weather_condition_Snow Pellets                                                             -0.000197
# Weather_condition_Snow Showers                                                             -0.001533
# Weather_condition_Snow Showers,Fog                                                         -0.000395
# Weather_condition_Snow,Blowing Snow                                                        -0.000861
# Weather_condition_Snow,Fog                                                                 -0.001202
# Weather_condition_Snow,Haze                                                                -0.000441
# Weather_condition_Snow,Ice Pellets                                                         -0.000483
# Weather_condition_Thunderstorms                                                            -0.000279
# Weather_condition_Thunderstorms,Heavy Rain Showers                                         -0.000197
# Weather_condition_Thunderstorms,Moderate Rain S...                                         -0.000197
# Weather_condition_Thunderstorms,Rain                                                       -0.000342
# Weather_condition_Thunderstorms,Rain Showers                                               -0.000790
# Weather_condition_Thunderstorms,Rain Showers,Fog                                            1.000000
# Weather_condition_Thunderstorms,Rain,Fog                                                   -0.000197
#
#                                                     Weather_condition_Thunderstorms,Rain,Fog
# Temp_C                                                                              0.010775
# Dew Point Temp_C                                                                    0.015732
# Humidity                                                                            0.012973
# Wind Speed_km/h                                                                     0.004980
# Visibility_km                                                                      -0.019329
# Press_kPa                                                                          -0.012284
# Year                                                                                     NaN
# Month                                                                               0.001504
# Day                                                                                 0.001505
# Hour                                                                               -0.010020
# Weather_condition_Clear                                                            -0.004499
# Weather_condition_Cloudy                                                           -0.005280
# Weather_condition_Drizzle                                                          -0.000731
# Weather_condition_Drizzle,Fog                                                      -0.001023
# Weather_condition_Drizzle,Ice Pellets,Fog                                          -0.000114
# Weather_condition_Drizzle,Snow                                                     -0.000161
# Weather_condition_Drizzle,Snow,Fog                                                 -0.000441
# Weather_condition_Fog                                                              -0.001406
# Weather_condition_Freezing Drizzle                                                 -0.000301
# Weather_condition_Freezing Drizzle,Fog                                             -0.000279
# Weather_condition_Freezing Drizzle,Haze                                            -0.000197
# Weather_condition_Freezing Drizzle,Snow                                            -0.000378
# Weather_condition_Freezing Fog                                                     -0.000228
# Weather_condition_Freezing Rain                                                    -0.000426
# Weather_condition_Freezing Rain,Fog                                                -0.000228
# Weather_condition_Freezing Rain,Haze                                               -0.000161
# Weather_condition_Freezing Rain,Ice Pellets,Fog                                    -0.000114
# Weather_condition_Freezing Rain,Snow Grains                                        -0.000114
# Weather_condition_Haze                                                             -0.000456
# Weather_condition_Mainly Clear                                                     -0.005992
# Weather_condition_Moderate Rain,Fog                                                -0.000114
# Weather_condition_Moderate Snow                                                    -0.000228
# Weather_condition_Moderate Snow,Blowing Snow                                       -0.000161
# Weather_condition_Mostly Cloudy                                                    -0.005923
# Weather_condition_Rain                                                             -0.002027
# Weather_condition_Rain Showers                                                     -0.001578
# Weather_condition_Rain Showers,Fog                                                 -0.000114
# Weather_condition_Rain Showers,Snow Showers                                        -0.000161
# Weather_condition_Rain,Fog                                                         -0.001234
# Weather_condition_Rain,Haze                                                        -0.000197
# Weather_condition_Rain,Ice Pellets                                                 -0.000114
# Weather_condition_Rain,Snow                                                        -0.000484
# Weather_condition_Rain,Snow Grains                                                 -0.000114
# Weather_condition_Rain,Snow,Fog                                                    -0.000114
# Weather_condition_Rain,Snow,Ice Pellets                                            -0.000228
# Weather_condition_Snow                                                             -0.002300
# Weather_condition_Snow Pellets                                                     -0.000114
# Weather_condition_Snow Showers                                                     -0.000885
# Weather_condition_Snow Showers,Fog                                                 -0.000228
# Weather_condition_Snow,Blowing Snow                                                -0.000497
# Weather_condition_Snow,Fog                                                         -0.000694
# Weather_condition_Snow,Haze                                                        -0.000255
# Weather_condition_Snow,Ice Pellets                                                 -0.000279
# Weather_condition_Thunderstorms                                                    -0.000161
# Weather_condition_Thunderstorms,Heavy Rain Showers                                 -0.000114
# Weather_condition_Thunderstorms,Moderate Rain S...                                 -0.000114
# Weather_condition_Thunderstorms,Rain                                               -0.000197
# Weather_condition_Thunderstorms,Rain Showers                                       -0.000456
# Weather_condition_Thunderstorms,Rain Showers,Fog                                   -0.000197
# Weather_condition_Thunderstorms,Rain,Fog                                            1.000000
#
# [60 rows x 60 columns]
# <ipython-input-22-0167b423f396>:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data_encoded.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5, annot_kws={"size": 8})
plt.title('Correlation Matrix')
plt.show()

#The correlation matrix can help identify relationships between different weather variables.

# %% [markdown]
# **Wind Speed Analysis**

# %%
# Plot a histogram of wind speeds
plt.figure(figsize=(10, 6))
sns.histplot(data['Wind Speed_km/h'], bins=20, color='skyblue', kde=True)
plt.title('Distribution of Wind Speeds')
plt.xlabel('Wind Speed (km/h)')
plt.ylabel('Frequency')
plt.show()

#The histogram of wind speeds provides an overview of the frequency of different wind speeds. It shows the most of the time the wind speed is nearer to 20km/h.

# %%
# Plot wind speed over time
plt.figure(figsize=(12, 6))
sns.lineplot(x='Date/Time', y='Wind Speed_km/h', data=data)
plt.title('Wind Speed Over Time')
plt.xlabel('Date/Time')
plt.ylabel('Wind Speed (km/h)')
plt.xticks(rotation=45)
plt.show()

#The line plot of wind speed over time can reveal trends or patterns in wind behavior. Sudden spikes in wind speed indicate storms or turbulent weather periods.

# %% [markdown]
# **Conclusion: Insights from Weather Data Analysis**

# %% [markdown]
# In summary, the exploratory data analysis (EDA) conducted on the weather dataset has revealed significant insights into atmospheric conditions during the observed period. Through a combination of statistical measures and visualizations, we've gained a deeper understanding of various meteorological parameters.
#
# **Key Findings:**
#
# *Temporal Patterns:*
#
# Analysis of temperature variations across months unveiled distinct seasonal patterns, indicating higher temperatures in summer and lower temperatures in winter.
# Day-to-day variations displayed fluctuations in temperature, humidity, and other factors, contributing to the dynamic nature of weather conditions.
#
# *Correlation Among Variables:*
#
# Correlation analysis highlighted meaningful relationships between different meteorological parameters. Notably, a positive correlation between temperature and humidity was observed.
# The correlation matrix provided valuable insights into how changes in one variable may influence others, contributing to a more holistic understanding of weather dynamics.
#
# *Wind Speed Distribution:*
#
# Examination of wind speed distribution showed the prevalence of calm conditions, with occasional spikes during specific periods.
# These findings are crucial for understanding the frequency and intensity of wind events, impacting sectors such as energy production and transportation.
#
# *Weather Condition Categorization:*
#
# Categorizing weather conditions enabled the identification of the frequency and duration of specific atmospheric states, including clear skies, snowy conditions, and foggy weather.
# This categorization enhances our ability to anticipate and prepare for specific weather phenomena, contributing to improved decision-making.
#
# *Implications and Applications:*
#
# Insights from this analysis have implications for various applications, including urban planning, agriculture, and emergency management.
# Understanding temporal and spatial patterns of weather conditions is crucial for making informed decisions across different sectors.
#
# *Limitations and Further Research:*
#
# Acknowledging the limitations, including potential biases in the dataset and the impact of localized weather phenomena, is essential.
# Future research may involve integrating additional datasets and employing advanced modeling techniques for more accurate predictions.
#
#
#
# ---
#
#
#
# In conclusion, our EDA provides a comprehensive overview of observed weather data, offering valuable insights that contribute to a better understanding of atmospheric dynamics. These findings can serve as a foundation for more targeted and in-depth analyses, driving advancements in weather prediction and the development of strategies for mitigating the impacts of extreme weather events.
